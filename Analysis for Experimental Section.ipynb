# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Top 10 groups for Each wave

# %%
rules = [{'year': 0, 'results': [{'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.18705360991978387, 'new_quality': 0.1806338803050874}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.1748036927263995, 'new_quality': 0.16554385601291569}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.15859778456703164, 'new_quality': 0.14963374210746386}, {'subgroup': "Hindsight=='Wrong' AND sex=='Woman'", 'penalty': 0.9409357260156487, 'old quality': 0.11069167029819355, 'new_quality': 0.10415374715591556}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.899846458370765, 'old quality': 0.10720072284615995, 'new_quality': 0.09646419078790298}, {'subgroup': "Poscountry=='Very negative effect'", 'penalty': 0.8994775812001404, 'old quality': 0.1067286568630396, 'new_quality': 0.09600003411990662}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND sex=='Woman'", 'penalty': 0.9405253529757319, 'old quality': 0.10353343339051443, 'new_quality': 0.09737581898440302}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.9201414616714412, 'old quality': 0.10038775733935809, 'new_quality': 0.0923709377721549}, {'subgroup': "EURef2016=='Remain' AND Poscountry=='Very negative effect'", 'penalty': 0.9174389657873118, 'old quality': 0.10038775733935809, 'new_quality': 0.0920996402711283}, {'subgroup': "EURef2016=='Remain' AND sex=='Woman'", 'penalty': 0.9451038468455941, 'old quality': 0.0952980277395335, 'new_quality': 0.09006653261343124}]}, {'year': 1, 'results': [{'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.19412720966705022, 'new_quality': 0.18746471222873617}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.18370998849355677, 'new_quality': 0.17397836057681187}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.172531130866341, 'new_quality': 0.16277956726849352}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.899846458370765, 'old quality': 0.12267260688502976, 'new_quality': 0.11038651084460316}, {'subgroup': "Poscountry=='Very negative effect'", 'penalty': 0.8994775812001404, 'old quality': 0.12112067024007928, 'new_quality': 0.10894532750088634}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.9201414616714412, 'old quality': 0.11450753651555418, 'new_quality': 0.10536313202181795}, {'subgroup': "EURef2016=='Remain' AND Poscountry=='Very negative effect'", 'penalty': 0.9174389657873118, 'old quality': 0.11430689035301439, 'new_quality': 0.10486959526783317}, {'subgroup': "Hindsight=='Wrong' AND sex=='Woman'", 'penalty': 0.9409357260156487, 'old quality': 0.11258297128302985, 'new_quality': 0.10593333982119663}, {'subgroup': "Govthand=='Very badly' AND Hindsight=='Wrong'", 'penalty': 0.7977758987995128, 'old quality': 0.11257887646338617, 'new_quality': 0.08981271435641722}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND sex=='Woman'", 'penalty': 0.9405253529757319, 'old quality': 0.1080459111178448, 'new_quality': 0.10161991869169554}]}, {'year': 2, 'results': [{'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.18423677643893946, 'new_quality': 0.1779137212980711}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.18423677643893946, 'new_quality': 0.10366109679375436}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.17807562644073185, 'new_quality': 0.16864246631823127}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.17807562644073185, 'new_quality': 0.09990909755132363}, {'subgroup': "EURef2016=='Remain' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5612786609430558, 'old quality': 0.17276625192292405, 'new_quality': 0.09697001053544944}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.17276625192292405, 'new_quality': 0.16300139914111916}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5603795992367091, 'old quality': 0.12432571021553895, 'new_quality': 0.06966959166540294}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.899846458370765, 'old quality': 0.12432571021553895, 'new_quality': 0.11187405002188278}, {'subgroup': "Poscountry=='Very negative effect'", 'penalty': 0.8994775812001404, 'old quality': 0.1238674815033019, 'new_quality': 0.11141602265194313}, {'subgroup': "Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5610033179563251, 'old quality': 0.1238674815033019, 'new_quality': 0.06949006811024609}]}, {'year': 3, 'results': [{'subgroup': "Hindsight=='Wrong' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.6793069686097218, 'old quality': 0.20290040561019212, 'new_quality': 0.1378316594647426}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.819714105489196, 'old quality': 0.20290040561019212, 'new_quality': 0.16632032448815368}, {'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.20290040561019212, 'new_quality': 0.1959368097550345}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.20290040561019212, 'new_quality': 0.11416221555754887}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.6822692889453535, 'old quality': 0.1874738749729389, 'new_quality': 0.12790766737361714}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.1874738749729389, 'new_quality': 0.10518197261111387}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.8213363061950759, 'old quality': 0.1874738749729389, 'new_quality': 0.15397909997835113}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.1874738749729389, 'new_quality': 0.17754286354396054}, {'subgroup': "EURef2016=='Remain' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.6849644227479361, 'old quality': 0.17560579427570872, 'new_quality': 0.12028372150725365}, {'subgroup': "EURef2016=='Remain' AND profile_gross_household=='Not Asked or missing' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.8227782916645666, 'old quality': 0.17560579427570872, 'new_quality': 0.14448463542056694}]}, {'year': 4, 'results': [{'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.18635935131002182, 'new_quality': 0.17996344883535895}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.18635935131002182, 'new_quality': 0.10485536670780804}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.1689322159809199, 'new_quality': 0.15998340768498362}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.1689322159809199, 'new_quality': 0.09477919905909406}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.1594370374231965, 'new_quality': 0.1504255598859099}, {'subgroup': "EURef2016=='Remain' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5612786609430558, 'old quality': 0.1594370374231965, 'new_quality': 0.08948860686961961}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.899846458370765, 'old quality': 0.11711999374421665, 'new_quality': 0.10539001157513951}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5603795992367091, 'old quality': 0.11711999374421665, 'new_quality': 0.06563165515699}, {'subgroup': "Poscountry=='Very negative effect'", 'penalty': 0.8994775812001404, 'old quality': 0.11642707885328016, 'new_quality': 0.10472354727314645}, {'subgroup': "Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5610033179563251, 'old quality': 0.11642707885328016, 'new_quality': 0.06531597753665286}]}, {'year': 5, 'results': [{'subgroup': "GEvote2015=='Missing' AND Hindsight=='Wrong'", 'penalty': 0.6809457385728819, 'old quality': 0.19465067337922737, 'new_quality': 0.13254654654792677}, {'subgroup': "GEvote2015=='Missing' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.8205496335078535, 'old quality': 0.19465067337922737, 'new_quality': 0.1597205387033819}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.19465067337922737, 'new_quality': 0.10952049142490797}, {'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.19465067337922737, 'new_quality': 0.18797021052716523}, {'subgroup': "EURef2016=='Remain' AND GEvote2015=='Missing' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.8234196084281183, 'old quality': 0.17079704864738163, 'new_quality': 0.14063763891790526}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.17079704864738163, 'new_quality': 0.09582546099013059}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.17079704864738163, 'new_quality': 0.1617494549898773}, {'subgroup': "EURef2016=='Remain' AND GEvote2015=='Missing' AND Hindsight=='Wrong'", 'penalty': 0.6860602441806861, 'old quality': 0.17079704864738163, 'new_quality': 0.11717706490036317}, {'subgroup': "EURef2016=='Remain' AND GEvote2015=='Missing' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.8246313824237718, 'old quality': 0.16239445806093278, 'new_quality': 0.13391556644874622}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.16239445806093278, 'new_quality': 0.1532158253251051}]}, {'year': 6, 'results': [{'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.19424669727367042, 'new_quality': 0.10929319366715338}, {'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.19424669727367042, 'new_quality': 0.18758009898893518}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.16661748895197204, 'new_quality': 0.1577912981705175}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.16661748895197204, 'new_quality': 0.09348052448379048}, {'subgroup': "EURef2016=='Remain' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5612786609430558, 'old quality': 0.1555150074934778, 'new_quality': 0.0872872551624885}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.1555150074934778, 'new_quality': 0.1467252054538261}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.899846458370765, 'old quality': 0.1266799088497653, 'new_quality': 0.11399246732519264}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5603795992367091, 'old quality': 0.1266799088497653, 'new_quality': 0.07098883655257432}, {'subgroup': "Poscountry=='Very negative effect'", 'penalty': 0.8994775812001404, 'old quality': 0.12586291815660067, 'new_quality': 0.1132108731862904}, {'subgroup': "Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5610033179563251, 'old quality': 0.12586291815660067, 'new_quality': 0.07060951469351837}]}, {'year': 7, 'results': [{'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.19961158673534105, 'new_quality': 0.19276086401819614}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.19961158673534105, 'new_quality': 0.11231175671695982}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.1745831476397755, 'new_quality': 0.16533499381158}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.1745831476397755, 'new_quality': 0.0979496468831166}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.1593487011852054, 'new_quality': 0.15034221646537982}, {'subgroup': "EURef2016=='Remain' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5612786609430558, 'old quality': 0.1593487011852054, 'new_quality': 0.0894390256242472}, {'subgroup': "Govthand=='Very badly' AND Hindsight=='Wrong'", 'penalty': 0.7977758987995128, 'old quality': 0.1529913677650455, 'new_quality': 0.12205282592732598}, {'subgroup': "Govthand=='Very badly' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5140276944290084, 'old quality': 0.1529913677650455, 'new_quality': 0.07864180003980685}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 'penalty': 0.899846458370765, 'old quality': 0.14248625641561347, 'new_quality': 0.12821575320209846}, {'subgroup': "Hindsight=='Wrong' AND Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5603795992367091, 'old quality': 0.14248625641561347, 'new_quality': 0.07984639126692045}]}, {'year': 8, 'results': [{'subgroup': "Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5626514900954651, 'old quality': 0.19228998142426196, 'new_quality': 0.1081922445787903}, {'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.19228998142426196, 'new_quality': 0.18569053814760908}, {'subgroup': "Govthand=='Very badly' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5140276944290084, 'old quality': 0.1717658701621152, 'new_quality': 0.08829241422102449}, {'subgroup': "Govthand=='Very badly' AND Hindsight=='Wrong'", 'penalty': 0.7977758987995128, 'old quality': 0.1717658701621152, 'new_quality': 0.13703067145166187}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.16109884131497454, 'new_quality': 0.15256498861403092}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.561048693458203, 'old quality': 0.16109884131497454, 'new_quality': 0.09038429443739683}, {'subgroup': "EURef2016=='Remain' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5612786609430558, 'old quality': 0.15004038286850752, 'new_quality': 0.08421446518381931}, {'subgroup': "EURef2016=='Remain'", 'penalty': 0.9434793967391196, 'old quality': 0.15004038286850752, 'new_quality': 0.141560009915286}, {'subgroup': "Poscountry=='Very negative effect' AND profile_gross_household=='Not Asked or missing'", 'penalty': 0.5610033179563251, 'old quality': 0.14943301842198936, 'new_quality': 0.08383241914696468}, {'subgroup': "Poscountry=='Very negative effect'", 'penalty': 0.8994775812001404, 'old quality': 0.14943301842198936, 'new_quality': 0.134411649961647}]}, {'year': 9, 'results': [{'subgroup': "GEvote2015=='Missing' AND Hindsight=='Wrong' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.8207206082520998, 'old quality': 0.19304452607440126, 'new_quality': 0.15843562085952095}, {'subgroup': "GEvote2015=='Missing' AND Hindsight=='Wrong'", 'penalty': 0.6809457385728819, 'old quality': 0.19304452607440126, 'new_quality': 0.13145284738518512}, {'subgroup': "Hindsight=='Wrong' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.6793069686097218, 'old quality': 0.19304452607440126, 'new_quality': 0.13113649181430193}, {'subgroup': "Hindsight=='Wrong'", 'penalty': 0.9656797341818235, 'old quality': 0.19304452607440126, 'new_quality': 0.1864191866247839}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.6822692889453535, 'old quality': 0.16754342194666214, 'new_quality': 0.11430973135902052}, {'subgroup': "EURef2016=='Remain' AND GEvote2015=='Missing' AND Hindsight=='Wrong'", 'penalty': 0.6860602441806861, 'old quality': 0.16754342194666214, 'new_quality': 0.11494488097159475}, {'subgroup': "EURef2016=='Remain' AND Hindsight=='Wrong'", 'penalty': 0.9470272248311299, 'old quality': 0.16754342194666214, 'new_quality': 0.15866818192485846}, {'subgroup': "EURef2016=='Remain' AND GEvote2015=='Missing' AND Hindsight=='Wrong' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.8238744079207919, 'old quality': 0.16754342194666214, 'new_quality': 0.13803473755732967}, {'subgroup': "EURef2016=='Remain' AND GEvote2015=='Missing'", 'penalty': 0.6882401587637432, 'old quality': 0.15818866934407536, 'new_quality': 0.10887179490399171}, {'subgroup': "EURef2016=='Remain' AND profile_gross_personal=='Not Asked or missing'", 'penalty': 0.6849644227479361, 'old quality': 0.15818866934407536, 'new_quality': 0.10835361058252871}]}]

# %%
rules[1]['results'][0]
# Out:
# {'subgroup': "Hindsight=='Wrong'",
#  'penalty': 0.9656797341818235,
#  'old quality': 0.19412720966705022,
#  'new_quality': 0.18746471222873617}

# %%
table1 = [["Year","Subgroup", "Penalty", "Old Quality", "New Quality"]]
for year in rules:
    for rule in year["results"]:
        row = [year["year"], rule["subgroup"], rule["penalty"],rule["old quality"],rule["new_quality"]]
        table1.append(row)

# %%
dataframe1 = pd.DataFrame(table1[1:],columns=table1[0])

# %%
dataframe1
# Out:
#     Year                                           Subgroup   Penalty  \
# 0      0                                 Hindsight=='Wrong'  0.965680
# 1      0         EURef2016=='Remain' AND Hindsight=='Wrong'  0.947027
# 2      0                                EURef2016=='Remain'  0.943479
# 3      0                Hindsight=='Wrong' AND sex=='Woman'  0.940936
# 4      0  Hindsight=='Wrong' AND Poscountry=='Very negat...  0.899846
# ..   ...                                                ...       ...
# 95     9  EURef2016=='Remain' AND GEvote2015=='Missing' ...  0.686060
# 96     9         EURef2016=='Remain' AND Hindsight=='Wrong'  0.947027
# 97     9  EURef2016=='Remain' AND GEvote2015=='Missing' ...  0.823874
# 98     9      EURef2016=='Remain' AND GEvote2015=='Missing'  0.688240
# 99     9  EURef2016=='Remain' AND profile_gross_personal...  0.684964
#
#     Old Quality  New Quality
# 0      0.187054     0.180634
# 1      0.174804     0.165544
# 2      0.158598     0.149634
# ...

# %%
unique = pd.unique(dataframe1["Subgroup"])
len(unique)
# Out:
# 31

# %% [markdown]
# ### Making a General Over view of basic statistics

# %%
overview_stats = [["Maximum", "Minimum", "Range","Number of Unique rules"]]
row = [dataframe["Penalty"].max(),dataframe["Penalty"].min(),dataframe["Penalty"].max()-dataframe["Penalty"].min(),len(unique)]
overview_stats.append(row)
overview_stats
# Out:
# [['Maximum', 'Minimum', 'Range', 'Number of Unique rules'],
#  [0.9656797341818235, 0.5140276944290084, 0.4516520397528151, 31]]

# %%
df_stats = pd.DataFrame(overview_stats,columns=overview_stats[0])

# %%
df_stats.drop(0)
# Out:
#    Maximum   Minimum     Range Number of Unique rules
# 1  0.96568  0.514028  0.451652                     31

# %% [markdown]
# # Top 10 of Wave 1

# %%
top10 = [["Subgroup", "Wave1","Wave2","Wave3","Wave4","Wave5","Wave6","Wave7","Wave8","Wave9","Wave10","Penalty"]]
row1 = ["Hindsight=='Wrong'", 0.18705360991978387, 0.19412720966705022, 0.18423677643893946, 0.20290040561019212, 0.18635935131002182, 0.19465067337922737, 0.19424669727367042, 0.19961158673534105, 0.19228998142426196, 0.19304452607440126, 0.9656797341818235]
row2 = ["EURef2016=='Remain' AND Hindsight=='Wrong'",0.1748036927263995, 0.18370998849355677, 0.17807562644073185, 0.1874738749729389, 0.1689322159809199, 0.17079704864738163, 0.16661748895197204, 0.1745831476397755, 0.16109884131497454, 0.16754342194666214,0.9470272248311299 ]
row3 = ["EURef2016=='Remain'",0.15859778456703164, 0.172531130866341, 0.17276625192292405, 0.17560579427570872, 0.1594370374231965, 0.16239445806093278, 0.1555150074934778, 0.1593487011852054, 0.15004038286850752, 0.02,0.7765101180149961 ]
row4 = ["Hindsight=='Wrong' AND sex=='Woman'",0.11069167029819355, 0.11258297128302985, 0.1024834749322398, 0.11707143722709133, 0.10220386033963692, 0.02, 0.11103725032888774, 0.11667343868743539, 0.12055421242724121, 0.02,0.6662105542375832]
row5 = ["Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 0.10720072284615995, 0.12267260688502976, 0.12432571021553895, 0.12445928852786241, 0.11711999374421665, 0.13383571381255444, 0.1266799088497653, 0.14248625641561347, 0.1493590054178282, 0.02,0.7454057619120436]
row6 = ["Poscountry=='Very negative effect'",0.1067286568630396, 0.12112067024007928, 0.1238674815033019, 0.12400588740674984, 0.11642707885328016, 0.13159175333377496, 0.12586291815660067, 0.14133015150107098, 0.14943301842198936, 0.02,0.7455743064382894]
row7 = ["EURef2016=='Remain' AND Hindsight=='Wrong' AND sex=='Woman'",0.10353343339051443, 0.1080459111178448, 0.02, 0.02, 0.09341173335881986, 0.02, 0.09441819748790437, 0.02, 0.02, 0.02,0.5627880072463974]
row8 = ["EURef2016=='Remain' AND Hindsight=='Wrong' AND Poscountry=='Very negative effect'",0.10038775733935809, 0.11450753651555418, 0.11631995586041792, 0.02, 0.10372001894112179, 0.02, 0.10803382974562122, 0.11988376092030746, 0.12622383745218244, 0.02,0.5728605128622081]
row9 = ["EURef2016=='Remain' AND Poscountry=='Very negative effect'",0.10038775733935809, 0.11430689035301439, 0.1175855399227869, 0.02, 0.10348904731080961, 0.02, 0.10724773999195822, 0.12015532008368812, 0.1267453620742869, 0.02,0.5712744031407933 ]
row10 = ["EURef2016=='Remain' AND sex=='Woman'",0.0952980277395335, 0.1057773810352523, 0.02, 0.02, 0.08931434008002191, 0.02, 0.02, 0.02, 0.02, 0.02,0.6231691038712803]
top10.append(row1)
top10.append(row2)
top10.append(row3)
top10.append(row4)
top10.append(row5)
top10.append(row6)
top10.append(row7)
top10.append(row8)
top10.append(row9)
top10.append(row10)

# %%
top10_noP = [["Subgroup", "Wave1","Wave2","Wave3","Wave4","Wave5","Wave6","Wave7","Wave8","Wave9","Wave10"]]
row1 = ["Hindsight=='Wrong'", 0.18705360991978387, 0.19412720966705022, 0.18423677643893946, 0.20290040561019212, 0.18635935131002182, 0.19465067337922737, 0.19424669727367042, 0.19961158673534105, 0.19228998142426196, 0.19304452607440126]
row2 = ["EURef2016=='Remain' AND Hindsight=='Wrong'",0.1748036927263995, 0.18370998849355677, 0.17807562644073185, 0.1874738749729389, 0.1689322159809199, 0.17079704864738163, 0.16661748895197204, 0.1745831476397755, 0.16109884131497454, 0.16754342194666214]
row3 = ["EURef2016=='Remain'",0.15859778456703164, 0.172531130866341, 0.17276625192292405, 0.17560579427570872, 0.1594370374231965, 0.16239445806093278, 0.1555150074934778, 0.1593487011852054, 0.15004038286850752, 0.02]
row4 = ["Hindsight=='Wrong' AND sex=='Woman'",0.11069167029819355, 0.11258297128302985, 0.1024834749322398, 0.11707143722709133, 0.10220386033963692, 0.02, 0.11103725032888774, 0.11667343868743539, 0.12055421242724121, 0.02]
row5 = ["Hindsight=='Wrong' AND Poscountry=='Very negative effect'", 0.10720072284615995, 0.12267260688502976, 0.12432571021553895, 0.12445928852786241, 0.11711999374421665, 0.13383571381255444, 0.1266799088497653, 0.14248625641561347, 0.1493590054178282, 0.02]
row6 = ["Poscountry=='Very negative effect'",0.1067286568630396, 0.12112067024007928, 0.1238674815033019, 0.12400588740674984, 0.11642707885328016, 0.13159175333377496, 0.12586291815660067, 0.14133015150107098, 0.14943301842198936, 0.02]
row7 = ["EURef2016=='Remain' AND Hindsight=='Wrong' AND sex=='Woman'",0.10353343339051443, 0.1080459111178448, 0.02, 0.02, 0.09341173335881986, 0.02, 0.09441819748790437, 0.02, 0.02, 0.02]
row8 = ["EURef2016=='Remain' AND Hindsight=='Wrong' AND Poscountry=='Very negative effect'",0.10038775733935809, 0.11450753651555418, 0.11631995586041792, 0.02, 0.10372001894112179, 0.02, 0.10803382974562122, 0.11988376092030746, 0.12622383745218244, 0.02]
row9 = ["EURef2016=='Remain' AND Poscountry=='Very negative effect'",0.10038775733935809, 0.11430689035301439, 0.1175855399227869, 0.02, 0.10348904731080961, 0.02, 0.10724773999195822, 0.12015532008368812, 0.1267453620742869, 0.02]
row10 = ["EURef2016=='Remain' AND sex=='Woman'",0.0952980277395335, 0.1057773810352523, 0.02, 0.02, 0.08931434008002191, 0.02, 0.02, 0.02, 0.02, 0.02]
top10_noP.append(row1)
top10_noP.append(row2)
top10_noP.append(row3)
top10_noP.append(row4)
top10_noP.append(row5)
top10_noP.append(row6)
top10_noP.append(row7)
top10_noP.append(row8)
top10_noP.append(row9)
top10_noP.append(row10)

# %%
dataframTop10 = pd.DataFrame(top10[1:],columns=top10[0])
dataframTop10_noP = pd.DataFrame(top10_noP[1:],columns=top10_noP[0])

# %%
dataframTop10
# Out:
#                                             Subgroup     Wave1     Wave2  \
# 0                                 Hindsight=='Wrong'  0.187054  0.194127
# 1         EURef2016=='Remain' AND Hindsight=='Wrong'  0.174804  0.183710
# 2                                EURef2016=='Remain'  0.158598  0.172531
# 3                Hindsight=='Wrong' AND sex=='Woman'  0.110692  0.112583
# 4  Hindsight=='Wrong' AND Poscountry=='Very negat...  0.107201  0.122673
# 5                 Poscountry=='Very negative effect'  0.106729  0.121121
# 6  EURef2016=='Remain' AND Hindsight=='Wrong' AND...  0.103533  0.108046
# 7  EURef2016=='Remain' AND Hindsight=='Wrong' AND...  0.100388  0.114508
# 8  EURef2016=='Remain' AND Poscountry=='Very nega...  0.100388  0.114307
# 9               EURef2016=='Remain' AND sex=='Woman'  0.095298  0.105777
#
#       Wave3     Wave4     Wave5     Wave6     Wave7     Wave8     Wave9  \
# 0  0.184237  0.202900  0.186359  0.194651  0.194247  0.199612  0.192290
# ...

# %%
dataframTop10_noP
# Out:
#                                             Subgroup     Wave1     Wave2  \
# 0                                 Hindsight=='Wrong'  0.187054  0.194127
# 1         EURef2016=='Remain' AND Hindsight=='Wrong'  0.174804  0.183710
# 2                                EURef2016=='Remain'  0.158598  0.172531
# 3                Hindsight=='Wrong' AND sex=='Woman'  0.110692  0.112583
# 4  Hindsight=='Wrong' AND Poscountry=='Very negat...  0.107201  0.122673
# 5                 Poscountry=='Very negative effect'  0.106729  0.121121
# 6  EURef2016=='Remain' AND Hindsight=='Wrong' AND...  0.103533  0.108046
# 7  EURef2016=='Remain' AND Hindsight=='Wrong' AND...  0.100388  0.114508
# 8  EURef2016=='Remain' AND Poscountry=='Very nega...  0.100388  0.114307
# 9               EURef2016=='Remain' AND sex=='Woman'  0.095298  0.105777
#
#       Wave3     Wave4     Wave5     Wave6     Wave7     Wave8     Wave9  \
# 0  0.184237  0.202900  0.186359  0.194651  0.194247  0.199612  0.192290
# ...

# %%
dataframTop10_noP.plot();

# %%
top10_stats = table1[0:9]

# %%
df_stats_top10 = pd.DataFrame(top10_stats[1:], columns = top10_stats[0])
df_stats_top10
# Out:
#    Year                                           Subgroup   Penalty  \
# 0     0                                 Hindsight=='Wrong'  0.965680
# 1     0         EURef2016=='Remain' AND Hindsight=='Wrong'  0.947027
# 2     0                                EURef2016=='Remain'  0.776510
# 3     0                Hindsight=='Wrong' AND sex=='Woman'  0.666211
# 4     0  Hindsight=='Wrong' AND Poscountry=='Very negat...  0.745406
# 5     0                 Poscountry=='Very negative effect'  0.745574
# 6     0  EURef2016=='Remain' AND Hindsight=='Wrong' AND...  0.562788
# 7     0  EURef2016=='Remain' AND Hindsight=='Wrong' AND...  0.572861
#
#    Old Quality  New Quality
# 0     0.187054     0.180634
# 1     0.174804     0.165544
# 2     0.158598     0.123153
# 3     0.110692     0.073744
# 4     0.107201     0.079908
# 5     0.106729     0.079574
# 6     0.103533     0.058267
# 7     0.100388     0.057508

# %%
df_stats_top10.to_csv("df_stats_top10.csv")
